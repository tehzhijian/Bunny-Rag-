# %%
import os
import json
import logging
import sys
import warnings
from typing import Dict, Any

# --- 1. GLOBAL SILENCING CONFIGURATION ---
os.environ["TQDM_DISABLE"] = "1"
os.environ["TRANSFORMERS_VERBOSITY"] = "error"
warnings.filterwarnings("ignore")

# --- 2. LOGGING SETUP ---
logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler(sys.stdout)]
)

noisy_loggers = ["sentence_transformers", "transformers", "urllib3", "requests", "huggingface_hub", "filelock", "tqdm"]
for logger_name in noisy_loggers:
    logging.getLogger(logger_name).setLevel(logging.ERROR)

from builder import CausalGraphBuilder
from bunny_retriever import BunnyPathRetriever
from explainer import CausalGraphExplainer

# %%
import logging
from typing import List, Tuple, Dict, Any
from builder import CausalGraphBuilder
from bunny_retriever import BunnyPathRetriever

# Setup logging to see the retrieval process
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class BunnyRAGChain:
    def __init__(self, model_name: str = "all-mpnet-base-v2", graph_path: str = "causal_math_graph_llm.json"):
        # Added encoding="utf-8" safety within the builder if it has a load method
        self.builder = CausalGraphBuilder(model_name=model_name)
        self.builder.load(graph_path) 
        self.retriever = BunnyPathRetriever(self.builder)
        self.graph_path = graph_path

    def explore_and_query(self, query: str):
        # 1. Retrieve ranked nodes using Effective Resistance
        top_results = self.retriever.retrieve_nodes_part2(
            query=query, 
            top_k=15, 
            labda=0.02, 
            json_path=self.graph_path
        )

        if not top_results:
            return "No direct causal paths found in the knowledge graph."

        # 2. Convert Node IDs to human-readable text
        # This is vital so the evaluator sees 'triangle' instead of 'node_123'
        retrieved_texts = [self.builder.node_text.get(nid, nid) for nid, score in top_results]

        # 3. Format context as a comma-separated string for the evaluator
        return ", ".join(retrieved_texts)

# --- Execution ---
if __name__ == "__main__":
    # Ensure causal_math_graph_llm.json is in your directory
    chain = BunnyRAGChain()
    
    # Example Query
    nodes = chain.explore_and_query('Tell me about surface tension and minimal surfaces.')
# Out:
# [('surface tension', 0.7634661197662354), ('repulsion between film surfaces', 0.45514827966690063), ('minimal area', 0.4434366226196289), ('discovery of a new surface', 0.3672070801258087), ('inhomogeneous surface concentrations', 0.36407333612442017)]

# %%
import logging
from typing import List, Tuple, Dict, Any
from builder import CausalGraphBuilder
from bunny_retriever import BunnyPathRetriever

class BunnyRAGChain:
    def __init__(self, model_name: str = "all-mpnet-base-v2", graph_path: str = "causal_math_graph_llm.json"):
        # Load the graph and initialize components
        self.builder = CausalGraphBuilder(model_name=model_name)
        self.builder.load(graph_path)
        self.retriever = BunnyPathRetriever(self.builder)
        self.graph_path = graph_path

    def generate_answer(self, query: str, retrieved_nodes: List[str]) -> str:
        """
        Synthesizes a sentence from the retrieved causal concepts.
        In a full RAG pipeline, this would be passed to an LLM.
        """
        if not retrieved_nodes:
            return "I couldn't find any causal relationships in the knowledge base to answer that."
        
        # Take the top 3-4 most relevant concepts
        concepts = ", ".join(retrieved_nodes[:4])
        
        # Simple template-based generation for demonstration
        return f"Regarding '{query}', the causal graph indicates relevance to: {concepts}."

    def explore_and_query(self, query: str):
        # 1. Retrieve ranked nodes using Effective Resistance
        top_results = self.retriever.retrieve_nodes_part2(
            query=query, 
            top_k=5, 
            labda=-0.01, 
            json_path=self.graph_path
        )

        if not top_results:
            return "No direct causal paths found."

        # 2. Map Node IDs to text
        retrieved_texts = [self.builder.node_text.get(nid, nid) for nid, score in top_results]

        # 3. Generate the final sentence
        return self.generate_answer(query, retrieved_texts)

# %%
# --- Execution with Test Questions ---
if __name__ == "__main__":
    chain = BunnyRAGChain()
    
    test_questions = [
        'What happens when the circumcenter is on the side of the triangle?',
        "how many side of squares",
        "what is the circumference of circle",
        "How is the area of a square related to its side length?",
        "What conditions make two triangles similar?",
        "What characterizes a tangential quadrilateral?",
        "What happens to a graph when a cut-set is removed?",
        "How is Brownian motion related to the diffusion constant?",
        "Why do soap films form minimal area surfaces?",
        "What is the relationship between snarks and the four-color theorem?"
    ]

    # print(f"{'Question':<70} | {'Generated Causal Explanation'}")
    # print("-" * 130)
    
    for question in test_questions:
        answer = chain.explore_and_query(question)
        print(f"{answer}")
        print()
# Out:
# [('a triangle changes shape', 0.5867527723312378), ('triangles are similar', 0.5511089563369751), ('a triangle will not change shape', 0.5075494050979614), ('tessellated triangles', 0.4814336895942688), ("the 'circles' in taxicab geometry", 0.4810835123062134)]
# Regarding 'What happens when the circumcenter is on the side of the triangle?', the causal graph indicates relevance to: minor-closed property, squared integer, inhomogeneous surface concentrations, convincing evidence of Brownian motion.
#
# [('construction of a square with a given side', 0.6614404916763306), ('squares tilted at 45° to the coordinate axes', 0.5511420965194702), ('a square is a regular polygon', 0.5356656908988953), ('formula for the area of a square as the second power of its side length', 0.5123594999313354), ('specifying the lengths of all three sides', 0.5033279657363892)]
# Regarding 'how many side of squares', the causal graph indicates relevance to: minor-closed property, squared integer, inhomogeneous surface concentrations, Marangoni forces.
#
# [('size of the circle', 0.8329709768295288), ('ratio of s to radius r or circumference C', 0.5655455589294434), ('length of the arc that subtends the angle at the centre of a unit circle', 0.510337769985199), ("shapes that would be Euclidean squares become the 'circles", 0.4091101288795471), ("angle's size θ", 0.40484219789505005)]
# Regarding 'what is the circumference of circle', the causal graph indicates relevance to: minor-closed property, squared integer, atoms and molecules exist, convincing evidence of Brownian motion.
#
# [('formula for the area of a square as the second power of its side length', 0.7187211513519287), ('a square is a regular polygon', 0.5529078841209412), ('area can be expressed using sides B and C and angle', 0.527953565120697), ('construction of a square with a given side', 0.5172773599624634), ('side length a', 0.46593427658081055)]
# Regarding 'How is the area of a square related to its side length?', the causal graph indicates relevance to: minor-closed property, squared integer, inhomogeneous surface concentrations, atoms and molecules exist.
#
# [('triangles are similar', 0.7750446796417236), ('a triangle changes shape', 0.579550564289093), ('one pair of corresponding sides of two triangles are in the same proportion as another pair of corresponding sides, and their included angles have the same measure', 0.5574780702590942), ('tessellated triangles', 0.5255328416824341), ('a triangle will not change shape', 0.5020112991333008)]
# Regarding 'What conditions make two triangles similar?', the causal graph indicates relevance to: minor-closed property, squared integer, convincing evidence of Brownian motion, inhomogeneous surface concentrations.
#
# [('the quadrilateral is a tangential quadrilateral', 0.8224164247512817), ('structural quadrilaterals', 0.6370924711227417), ('orthodiagonal quadrilateral', 0.6075687408447266), ('internal angle bisectors of a convex quadrilateral are concurrent', 0.490739107131958), ('splitting the quadrilateral into two rigid triangles', 0.47062429785728455)]
# Regarding 'What characterizes a tangential quadrilateral?', the causal graph indicates relevance to: minor-closed property, squared integer, inhomogeneous surface concentrations, convincing evidence of Brownian motion.
#
# [('removal of a cut-set', 0.7757296562194824), ('disconnection of graph', 0.5512887239456177), ('cut whose cut-set has minimum total weight', 0.5328983664512634), ('max-flow min-cut theorem', 0.5249670147895813), ('vertex removal', 0.4933454692363739)]
# Regarding 'What happens to a graph when a cut-set is removed?', the causal graph indicates relevance to: squared integer, minor-closed property, convincing evidence of Brownian motion, inhomogeneous surface concentrations.
#
# [('diffusion constant', 0.6872995495796204), ('analog of Brownian motion', 0.5670863389968872), ('Brownian motion in a massive body', 0.5556885004043579), ('true Brownian dynamics', 0.5458659529685974), ('convincing evidence of Brownian motion', 0.521973192691803)]
# Regarding 'How is Brownian motion related to the diffusion constant?', the causal graph indicates relevance to: minor-closed property, squared integer, convincing evidence of Brownian motion, Marangoni forces.
#
# [('the soap film to thin at the top', 0.6689727306365967), ('the liquid tends to drain in a vertical soap film', 0.6225847005844116), ('unstable soap film', 0.6012915372848511), ('hole in soap film', 0.5908858180046082), ('soap film does not last forever', 0.5706585049629211)]
# Regarding 'Why do soap films form minimal area surfaces?', the causal graph indicates relevance to: squared integer, minor-closed property, unstable soap film, Marangoni forces.
#
# [('four-color theorem proven', 0.6242268085479736), ('all snarks shown to be non-planar', 0.561956524848938), ('violation of snark definition', 0.5531005859375), ('required for snarks', 0.49014514684677124), ('prevents 3-edge-coloring', 0.3543957769870758)]
# Regarding 'What is the relationship between snarks and the four-color theorem?', the causal graph indicates relevance to: squared integer, minor-closed property, inhomogeneous surface concentrations, convincing evidence of Brownian motion.
